# %%
import pandas as pd
import numpy as np

# %%
sensor_names=[f's{i}' for i in range(1,22)]
settings=['set_1','set_2','set_3']
cols=['unit_nr','time']+settings+sensor_names

# %%
cols
# Out:
# ['unit_nr',
#  'time',
#  'set_1',
#  'set_2',
#  'set_3',
#  's1',
#  's2',
#  's3',
#  's4',
#  's5',
#  's6',
#  's7',
#  's8',
#  's9',
#  's10',
#  's11',
#  's12',
#  's13',
#  's14',
#  's15',
#  's16',
#  's17',
#  's18',
#  's19',
#  's20',
#  's21']

# %%
train=pd.read_csv('CMAPSSData/train_FD001.txt',sep='\s+',names=cols)

# %%
train
# Out:
#        unit_nr  time   set_1   set_2  set_3      s1      s2       s3       s4  \
# 0            1     1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1            1     2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2            1     3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3            1     4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4            1     5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
# ...        ...   ...     ...     ...    ...     ...     ...      ...      ...
# 20626      100   196 -0.0004 -0.0003  100.0  518.67  643.49  1597.98  1428.63
# 20627      100   197 -0.0016 -0.0005  100.0  518.67  643.54  1604.50  1433.58
# 20628      100   198  0.0004  0.0000  100.0  518.67  643.42  1602.46  1428.18
# 20629      100   199 -0.0011  0.0003  100.0  518.67  643.23  1605.26  1426.53
# 20630      100   200 -0.0032 -0.0005  100.0  518.67  643.85  1600.38  1432.14
#
# ...

# %%
train.loc[train['unit_nr']==1].describe()
# Out:
#        unit_nr        time       set_1       set_2  set_3      s1          s2  \
# count    192.0  192.000000  192.000000  192.000000  192.0  192.00  192.000000
# mean       1.0   96.500000   -0.000189    0.000048  100.0  518.67  642.621042
# std        0.0   55.569776    0.001953    0.000282    0.0    0.00    0.486795
# min        1.0    1.000000   -0.006700   -0.000400  100.0  518.67  641.710000
# 25%        1.0   48.750000   -0.001425   -0.000200  100.0  518.67  642.272500
# 50%        1.0   96.500000    0.000000    0.000100  100.0  518.67  642.540000
# 75%        1.0  144.250000    0.001000    0.000300  100.0  518.67  642.882500
# max        1.0  192.000000    0.004700    0.000500  100.0  518.67  644.210000
#
#                 s3           s4            s5  ...         s12          s13  \
# count   192.000000   192.000000  1.920000e+02  ...  192.000000   192.000000
# mean   1589.485521  1407.262135  1.462000e+01  ...  521.459427  2388.110833
# ...
